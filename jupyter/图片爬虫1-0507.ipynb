# %%
import requests
from lxml import etree 
from bs4 import BeautifulSoup
myheader={'User-Agent':'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.108 Safari/537.36'}
url1="http://www.httpbin.org"
url2="http://www.baidu.com"
url3="http://www.douban.com"
url="https://www.tutudao.net/"
url5='http://www.meinvtu.site/list-cateId-2.html?page=1'
index=requests.get(url,myheader)
html=etree.HTML(index.content)
myurls=html.xpath('//li/a/@href')
# print(index.status_code)
for myurl in myurls:
        myurl1='https://www.tutudao.net'+myurl
        def imgspider(url):
            re=requests.get(myurl1,myheader)
            mytext=re.content
            html=etree.HTML(mytext)
            text1=html.xpath('//img/@src')
            for text in text1:
                imgsite='https://www.tutudao.net'+text
                print (imgsite)
        imgspider(myurl1)  
# text=BeautifulSoup(mytext,'html.parser')
# print (text.findall(img))
# Out:
# 200
# https://www.tutudao.net/uploads/allimg/bigimg/20191011/yxpyrnbslhd10379.jpg
# https://www.tutudao.net/uploads/allimg/bigimg/20191011/qka4srqrcf310380.jpg
# https://www.tutudao.net/uploads/allimg/bigimg/20191011/p2wab2e5uyj10381.jpg
# https://www.tutudao.net/uploads/allimg/bigimg/20191011/cnocbvjqjct10382.jpg
# https://www.tutudao.net/uploads/allimg/bigimg/20191011/0zbaitfpv2x10383.jpg
# https://www.tutudao.net/uploads/allimg/bigimg/20191011/bob3a3gig0d10384.jpg
# https://www.tutudao.net/uploads/allimg/bigimg/20191011/zpdoc3owbql10385.jpg
# https://www.tutudao.net/uploads/allimg/smallimg/20191011/dwyyoazebtz28.jpg
# https://www.tutudao.net/uploads/allimg/smallimg/20191011/owneniue5gw23.jpg
# https://www.tutudao.net/uploads/allimg/smallimg/20191011/gtxusupsqbo36.jpg
# https://www.tutudao.net/uploads/allimg/smallimg/20191011/4n1kpfyrati12.jpg
# https://www.tutudao.net/uploads/allimg/smallimg/20191011/tus0yntgp2l25.jpg
# ...
