# %%
# IP地址取自国内髙匿代理IP网站：http://www.xicidaili.com/nn/
# 仅仅爬取首页IP地址就足够一般使用
 
from bs4 import BeautifulSoup
import requests
import random
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.108 Safari/537.36'}
# myproxy={'https':'27.184.146.96:8118'}
def getHTMLText(url,proxies):
    try:
        r = requests.get(url,proxies=myproxy)
        r.raise_for_status()
        r.encoding = r.apparent_encoding
    except:
        return 0
    else:
        return r.text
def get_ip_list(url):
    web_data = requests.get(url,headers=headers)
    soup = BeautifulSoup(web_data.text, 'html')
    ips = soup.find_all('tr')
#     print(ips)
    ip_list = []
    for i in range(1, len(ips)):
        ip_dict={}
        ip_info = ips[i]
        tds = ip_info.find_all('td')
        http1=tds[5].text
        ip1=tds[1].text + ':' + tds[2].text
        ip_dict[http1]=ip1
        ip_list.append(ip_dict)
# 检测ip可用性，移除不可用ip：（这里其实总会出问题，你移除的ip可能只是暂时不能用，剩下的ip使用一次后可能之后也未必能用）
    for ip in ip_list:
        try:
          res = requests.get(url1,proxies=ip,headers=headers,timeout=1)
        except Exception as e:
          ip_list.remove(ip)
          continue
    return ip_list
def get_random_ip(ip_list):
    proxy_list = []
    for ip in ip_list:
        proxy_list.append(ip)
    proxy_ip = random.choice(proxy_list)
    print(proxy_ip)
    return proxy_ip
if __name__ == '__main__':
    url = 'http://www.xicidaili.com/nn/'
    for i in range(1,5):
        urls=url+str(i)
        ip_list = get_ip_list(urls)
#         print('IP列表：',ip_list)
    proxies = get_random_ip(ip_list)
    print(proxies)
# Out:
# {'HTTP': '183.165.30.84:4216'}
# {'HTTP': '183.165.30.84:4216'}

# %%
import requests
import json
from lxml import etree
from bs4 import BeautifulSoup
myproxy=proxies
print(myproxy)
headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.108 Safari/537.36'}
def get_url(base_url):#
    ress=[]
    for i in range(1,3):
        url=base_url+str(i)+'.html'
        res=requests.get(url,proxies=myproxy,headers=headers).text
        index_html=etree.HTML(res)
        story_urls=index_html.xpath('//div[@class="list_article"]/ul/li/a/@href')
        for story_url in story_urls:
            ress.append('http://chunchao.xyz'+story_url)
    return ress
def get_story(ress_url):
    res=requests.get(ress_url,headers=headers,proxies=myproxy).content
#     index_html=etree.HTML(res)
    index_html=BeautifulSoup(res, 'html')
#     text1=index_html.xpath('//book/p//text()')
    text1=soup.find_all('book')
    print(text1)
    for text in text1:
        print(text)
#     return text
if __name__ == '__main__':
    base_url='http://chunchao.xyz/?s=book/type/26/'
    ress=get_url(base_url)
    for ress_url in ress:
        print(ress_url,'\n')
        html=requests.get(ress_url,headers=headers,proxies=myproxy).text
        soup=BeautifulSoup(html, 'html')
        texts=soup.find_all("book")
        print(texts)
#         index_html=etree.HTML(html)
#         texts=index_html.xpath('//book/p/text()')
        for text in texts:
            print(text)
            with open ('2.txt','wb') as f :
                f.write(text)
        print("写入完成")
#         text=get_story(ress_url)        
#         with open ('','a') as f:
#                 f.write()
# Out:
# {'HTTP': '183.165.30.84:4216', 'http': 'http://127.0.0.1:7890', 'https': 'https://127.0.0.1:7890', 'ftp': 'ftp://127.0.0.1:7890'}
# http://chunchao.xyz/?s=book/view/id/15758.html
#
# []
# 写入完成
# http://chunchao.xyz/?s=book/view/id/15763.html
#
# []
# 写入完成
# http://chunchao.xyz/?s=book/view/id/15751.html
#
# []
# 写入完成
# http://chunchao.xyz/?s=book/view/id/15747.html
#
# []
# 写入完成
# http://chunchao.xyz/?s=book/view/id/15741.html
#
# []
# 写入完成
# http://chunchao.xyz/?s=book/view/id/15731.html
#
# []
# 写入完成
# http://chunchao.xyz/?s=book/view/id/15737.html
#
# []
# 写入完成
# http://chunchao.xyz/?s=book/view/id/15726.html
#
# []
# 写入完成
# http://chunchao.xyz/?s=book/view/id/15627.html
#
# []
# 写入完成
# http://chunchao.xyz/?s=book/view/id/15720.html
#
# []
# 写入完成
# http://chunchao.xyz/?s=book/view/id/15634.html
#
# []
# 写入完成
# http://chunchao.xyz/?s=book/view/id/15637.html
#
# []
# 写入完成
# http://chunchao.xyz/?s=book/view/id/15640.html
#
# []
# 写入完成
# http://chunchao.xyz/?s=book/view/id/15644.html
#
# []
# 写入完成
# http://chunchao.xyz/?s=book/view/id/15648.html
#
# []
# 写入完成
# http://chunchao.xyz/?s=book/view/id/15656.html
#
# []
# 写入完成
# http://chunchao.xyz/?s=book/view/id/15652.html
#
# []
# 写入完成
# http://chunchao.xyz/?s=book/view/id/15660.html
#
# []
# 写入完成
# http://chunchao.xyz/?s=book/view/id/15664.html
#
# []
# 写入完成
# http://chunchao.xyz/?s=book/view/id/15669.html
#
# []
# 写入完成
# http://chunchao.xyz/?s=book/view/id/15674.html
#
# []
# 写入完成
# http://chunchao.xyz/?s=book/view/id/15683.html
#
# []
# 写入完成
# http://chunchao.xyz/?s=book/view/id/15679.html
#
# []
# 写入完成
# http://chunchao.xyz/?s=book/view/id/15689.html
#
# []
# 写入完成
# http://chunchao.xyz/?s=book/view/id/15695.html
#
# []
# 写入完成
# http://chunchao.xyz/?s=book/view/id/15700.html
#
# []
# 写入完成
# http://chunchao.xyz/?s=book/view/id/15710.html
#
# []
# 写入完成
# http://chunchao.xyz/?s=book/view/id/15705.html
#
# []
# 写入完成
# http://chunchao.xyz/?s=book/view/id/15715.html
#
# []
# 写入完成
# http://chunchao.xyz/?s=book/view/id/15559.html
#
# []
# 写入完成
# http://chunchao.xyz/?s=book/view/id/15564.html
#
# []
# 写入完成
# http://chunchao.xyz/?s=book/view/id/15566.html
#
# []
# 写入完成
# http://chunchao.xyz/?s=book/view/id/15568.html
#
# []
# 写入完成
# http://chunchao.xyz/?s=book/view/id/15577.html
#
# []
# 写入完成
# http://chunchao.xyz/?s=book/view/id/15573.html
#
# []
# 写入完成
# http://chunchao.xyz/?s=book/view/id/15581.html
#
# []
# 写入完成
# http://chunchao.xyz/?s=book/view/id/15586.html
#
# []
# 写入完成
# http://chunchao.xyz/?s=book/view/id/15589.html
#
# []
# 写入完成
# http://chunchao.xyz/?s=book/view/id/15595.html
#
# []
# 写入完成
# http://chunchao.xyz/?s=book/view/id/15592.html
#
# []
# 写入完成

# %% [markdown]
# ###你好

# %%
import requests
import json
from lxml import etree
from bs4 import BeautifulSoup
url="http://chunchao.xyz/?s=book/view/id/15564.html"
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.108 Safari/537.36'}
html=requests.get(url,headers=headers).text
soup=BeautifulSoup(html, 'html.parser')
texts=soup.find_all("book")
print(texts)
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# c:\program files\python37\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     676                 headers=headers,
# --> 677                 chunked=chunked,
#     678             )
#
# c:\program files\python37\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# c:\program files\python37\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# c:\program files\python37\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#
# c:\program files\python37\lib\http\client.py in getresponse(self)
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#
# c:\program files\python37\lib\http\client.py in begin(self)
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#
# c:\program files\python37\lib\http\client.py in _read_status(self)
#     264             # sending a valid response.
# --> 265             raise RemoteDisconnected("Remote end closed connection without"
#     266                                      " response")
#
# RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# c:\program files\python37\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# c:\program files\python37\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     724             retries = retries.increment(
# --> 725                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     726             )
#
# c:\program files\python37\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     438         if new_retry.is_exhausted():
# --> 439             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     440
#
# MaxRetryError: HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://chunchao.xyz/?s=book/view/id/15564.html (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
#
# During handling of the above exception, another exception occurred:
#
# ProxyError                                Traceback (most recent call last)
# <ipython-input-2-b8349dbf92ea> in <module>
#       5 url="http://chunchao.xyz/?s=book/view/id/15564.html"
#       6 headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.108 Safari/537.36'}
# ----> 7 html=requests.get(url,headers=headers).text
#       8 soup=BeautifulSoup(html, 'html.parser')
#       9 texts=soup.find_all("book/p/text()")
#
# c:\program files\python37\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# c:\program files\python37\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# c:\program files\python37\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# c:\program files\python37\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# c:\program files\python37\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     508
#     509             if isinstance(e.reason, _ProxyError):
# --> 510                 raise ProxyError(e, request=request)
#     511
#     512             if isinstance(e.reason, _SSLError):
#
# ProxyError: HTTPConnectionPool(host='127.0.0.1', port=7890): Max retries exceeded with url: http://chunchao.xyz/?s=book/view/id/15564.html (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
